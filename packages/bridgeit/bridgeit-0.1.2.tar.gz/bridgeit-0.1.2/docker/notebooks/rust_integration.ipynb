# %% [markdown]
# # Rust Bridge Smoke Test

# %%
# !pip install -U bridgeit

# %%
import bridgeit

# %%
bridgeit.help()

# %%
bridgeit.langs()

# %%
bridgeit.install("rust", force=True, step=1)

# %%
bridgeit.install("rust", force=True, step=2)

# %%
bridgeit.install("rust", force=True, step=3)

# %%
bridgeit.use("rust")

# %%
# %%rust
# fn main() {
#     println!("Hello from Rust 🦀");
# }
# main()

# %%
# %%rust
# let value = 21;
# println!("{}", value * 2);

# %%
# %%rust
# value = 5;
