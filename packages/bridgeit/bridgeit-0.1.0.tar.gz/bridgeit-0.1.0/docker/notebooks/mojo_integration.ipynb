# %% [markdown]
# # Mojo Bridge Smoke Test

# %%
# !pip install -U bridgeit

# %%
import bridgeit

# %%
bridgeit.help()

# %%
bridgeit.langs()

# %%
bridgeit.install('mojo', force=True)

# %%
bridgeit.use('mojo')

# %%
# %%mojo
# fn main():
#     print("Hello from Mojo 🔥")
# main()

# %%
# %%mojo
# alias value = 10
# print(value * 3)
